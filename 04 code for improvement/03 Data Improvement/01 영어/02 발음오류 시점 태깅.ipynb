# %% [markdown]
# # 필요 라이브러리 설치

# %%
# !pip3 install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pickle5
#   Downloading pickle5-0.0.12-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (256 kB)
#      |████████████████████████████████| 256 kB 4.1 MB/s
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.12

# %% [markdown]
# # 필요 라이브러리 로드

# %%
import numpy as np
import pandas as pd

from tqdm import tqdm_notebook
from pickle5 import pickle

# %% [markdown]
# # 데이터 로드

# %%
errorInfoPath = '/content/drive/MyDrive/Data enhancement code for speech recognition/05  Data for improvement/외국인 음성 데이터셋/Error Information data/영어/01errorInfoDict.p'
with open(errorInfoPath, "rb") as f:
    errorInfoDict = pickle.load(f)

# %% [markdown]
# # error Tagging DataFrame 생성

# %%
ErrorDict = {
    'file name' : [],
    'file length' : [],
    'number of errors' : [],
    'time of error' : [],
}
for key in tqdm_notebook(list(errorInfoDict)):
    ErrorDict['file name'].append(key)
    ErrorDict['file length'].append(len(errorInfoDict[key]))
    tempErrorTime = []
    for i in range(len(errorInfoDict[key])):
        if errorInfoDict[key][i] == 3:
            tempErrorTime.append(i)
    
    tempErrorSection = []
    for i in range(len(tempErrorTime)-1):
        check = True
        for j in range(tempErrorTime[i] + 1, tempErrorTime[i+1] - 1):
            if errorInfoDict[key][j] != 4:
                check = False
                break
        
        if check:
            tempErrorSection.append((tempErrorTime[i], tempErrorTime[i+1]))
        else:
            tempErrorSection.append((tempErrorTime[i], tempErrorTime[i]))
    
    while True:
        check = True
        for i in range(len(tempErrorSection) - 1):
            if tempErrorSection[i][1] == tempErrorSection[i + 1][0]:
                tempErrorSection[i] = (tempErrorSection[i][0], tempErrorSection[i+1][1])
                check = False
                del tempErrorSection[i+1]
                break
        if check:
            break

    for i in range(len(tempErrorSection)):
        tempSection = (tempErrorSection[i][0] * 320, (tempErrorSection[i][1] + 1) * 320)
        tempErrorSection[i] = tempSection

    ErrorDict['number of errors'].append(len(tempErrorSection))
    ErrorDict['time of error'].append(tempErrorSection)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
#   0%|          | 0/25152 [00:00<?, ?it/s]

# %%
ErrorInfoDf = pd.DataFrame(ErrorDict)

# %% [markdown]
# # DataFrame

# %%
ErrorInfoDf
# Out:
#                            file name  file length  number of errors  \
# 0      EN10QC259_EN0101_20211101.wav          354                 0
# 1      EN10QC248_EN0119_20211025.wav          354                 0
# 2      EN40QB231_EN0101_20211109.wav          354                 1
# 3      EN10QC251_EN0101_20211101.wav          354                 0
# 4      EN30QA282_EN0051_20210919.wav          354                 0
# ...                              ...          ...               ...
# 25147  EN50QA247_EN0051_20210912.wav         4371                 0
# 25148  EN50QA273_EN0051_20210912.wav         4371                 0
# 25149  EN40QB256_EN0051_20210906.wav         4371                 0
# 25150  EN20QB258_EN0051_20210915.wav         4371                 0
# 25151  EN50QA299_EN0051_20210912.wav         4371                 0
#
#       time of error
# 0                []
# 1                []
# 2       [(0, 1600)]
# 3                []
# 4                []
# ...             ...
# 25147            []
# 25148            []
# 25149            []
# 25150            []
# 25151            []
#
# [25152 rows x 4 columns]

# %%
ErrorInfoDf[ErrorInfoDf['number of errors'] > 0]
# Out:
#                            file name  file length  number of errors  \
# 2      EN40QB231_EN0101_20211109.wav          354                 1
# 6      EN30QA283_EN0051_20210919.wav          354                 1
# 7      EN30QA284_EN0051_20210919.wav          354                 1
# 8      EN10QC240_EN0101_20211101.wav          354                 1
# 9      EN30QA248_EN0051_20210919.wav          354                 1
# ...                              ...          ...               ...
# 24989  EN13RC069_EN0094_20211031.wav         2189                 1
# 25052  EN40QB232_EN0051_20210906.wav         2189                 1
# 25084  EN12RC040_EN0151_20211102.wav         2189                 1
# 25098  EN13RC058_EN0151_20211102.wav         4371                 1
# 25124  EN31RA001_EN0320_20211111.wav         4371                 1
#
#             time of error
# 2             [(0, 1600)]
# 6        [(43840, 47360)]
# 7        [(46720, 47680)]
# 8        [(36480, 41280)]
# 9        [(45440, 46400)]
# ...                   ...
# 24989  [(534080, 536000)]
# 25052      [(4800, 6080)]
# 25084    [(96000, 96320)]
# 25098  [(665600, 666560)]
# 25124  [(758080, 768640)]
#
# [557 rows x 4 columns]

# %% [markdown]
# # DataFrame 저장

# %%
dfPath = '/content/drive/MyDrive/Data enhancement code for speech recognition/05  Data for improvement/외국인 음성 데이터셋/Error Information data/영어/02EnglishErrorInfoDf.p'
ErrorInfoDf.to_pickle(dfPath)

# %%
dfPath = '/content/drive/MyDrive/Data enhancement code for speech recognition/05  Data for improvement/외국인 음성 데이터셋/Error Information data/영어/02EnglishErrorInfoDf.csv'

ErrorInfoDf.to_csv(dfPath)
