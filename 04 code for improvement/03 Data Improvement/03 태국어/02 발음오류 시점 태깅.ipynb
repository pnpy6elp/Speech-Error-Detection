# %% [markdown]
# # 필요 라이브러리 설치

# %%
# !pip3 install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pickle5
#   Downloading pickle5-0.0.12-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (256 kB)
#      |████████████████████████████████| 256 kB 9.2 MB/s
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.12

# %% [markdown]
# # 필요 라이브러리 로드

# %%
import numpy as np
import pandas as pd

from tqdm import tqdm_notebook
from pickle5 import pickle

# %% [markdown]
# # 데이터 로드

# %%
errorInfoPath = '/content/drive/MyDrive/Data enhancement code for speech recognition/05  Data for improvement/외국인 음성 데이터셋/Error Information data/태국어/01errorInfoDict.p'
with open(errorInfoPath, "rb") as f:
    errorInfoDict = pickle.load(f)

# %% [markdown]
# # error Tagging DataFrame 생성

# %%
ErrorDict = {
    'file name' : [],
    'file length' : [],
    'number of errors' : [],
    'time of error' : [],
}
for key in tqdm_notebook(list(errorInfoDict)):
    ErrorDict['file name'].append(key)
    ErrorDict['file length'].append(len(errorInfoDict[key]))
    tempErrorTime = []
    for i in range(len(errorInfoDict[key])):
        if errorInfoDict[key][i] == 3:
            tempErrorTime.append(i)
    
    tempErrorSection = []
    for i in range(len(tempErrorTime)-1):
        check = True
        for j in range(tempErrorTime[i] + 1, tempErrorTime[i+1] - 1):
            if errorInfoDict[key][j] != 4:
                check = False
                break
        
        if check:
            tempErrorSection.append((tempErrorTime[i], tempErrorTime[i+1]))
        else:
            tempErrorSection.append((tempErrorTime[i], tempErrorTime[i]))
    
    while True:
        check = True
        for i in range(len(tempErrorSection) - 1):
            if tempErrorSection[i][1] == tempErrorSection[i + 1][0]:
                tempErrorSection[i] = (tempErrorSection[i][0], tempErrorSection[i+1][1])
                check = False
                del tempErrorSection[i+1]
                break
        if check:
            break

    for i in range(len(tempErrorSection)):
        tempSection = (tempErrorSection[i][0] * 320, (tempErrorSection[i][1] + 1) * 320)
        tempErrorSection[i] = tempSection

    ErrorDict['number of errors'].append(len(tempErrorSection))
    ErrorDict['time of error'].append(tempErrorSection)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
#   0%|          | 0/111595 [00:00<?, ?it/s]

# %%
ErrorInfoDf = pd.DataFrame(ErrorDict)

# %% [markdown]
# # DataFrame 확인

# %%
ErrorInfoDf
# Out:
#                             file name  file length  number of errors  \
# 0       TH10QC248_TH0146_20211030.wav          362                 2
# 1       TH10QC291_TH0148_20211020.wav          362                 1
# 2       TH10QC274_TH0145_20211030.wav          362                 1
# 3       TH10QC273_TH0051_20210806.wav          362                 1
# 4       TH10QC251_TH0148_20211020.wav          362                 2
# ...                               ...          ...               ...
# 111590  TH57RA162_TH0295_20211117.wav          515                 0
# 111591  TH58RA192_TH0060_20210826.wav          515                 0
# 111592  TH59RA221_TH0295_20211118.wav          515                 1
# 111593  TH59RA223_TH0185_20211025.wav          515                 0
# 111594  TH59RA224_TH0095_20211118.wav          515                 1
#
#                       time of error
# 0         [(0, 320), (5760, 11520)]
# 1                  [(18880, 23040)]
# 2                       [(0, 1600)]
# 3                       [(0, 1600)]
# 4       [(0, 3840), (16320, 22720)]
# ...                             ...
# 111590                           []
# 111591                           []
# 111592                  [(0, 2880)]
# 111593                           []
# 111594             [(48000, 49280)]
#
# [111595 rows x 4 columns]

# %%
ErrorInfoDf[ErrorInfoDf['number of errors'] > 0]
# Out:
#                             file name  file length  number of errors  \
# 0       TH10QC248_TH0146_20211030.wav          362                 2
# 1       TH10QC291_TH0148_20211020.wav          362                 1
# 2       TH10QC274_TH0145_20211030.wav          362                 1
# 3       TH10QC273_TH0051_20210806.wav          362                 1
# 4       TH10QC251_TH0148_20211020.wav          362                 2
# ...                               ...          ...               ...
# 111582  TH54RA076_TH0118_20210817.wav          515                 3
# 111585  TH54RA086_TH0240_20211104.wav          515                 1
# 111588  TH57RA153_TH0263_20211108.wav          515                 1
# 111592  TH59RA221_TH0295_20211118.wav          515                 1
# 111594  TH59RA224_TH0095_20211118.wav          515                 1
#
#                                            time of error
# 0                              [(0, 320), (5760, 11520)]
# 1                                       [(18880, 23040)]
# 2                                            [(0, 1600)]
# 3                                            [(0, 1600)]
# 4                            [(0, 3840), (16320, 22720)]
# ...                                                  ...
# 111582  [(1600, 1920), (16000, 17280), (108480, 109760)]
# 111585                                     [(960, 1280)]
# 111588                                [(118400, 119680)]
# 111592                                       [(0, 2880)]
# 111594                                  [(48000, 49280)]
#
# [21039 rows x 4 columns]

# %% [markdown]
# # DataFrame 저장

# %%
dfPath = '/content/drive/MyDrive/Data enhancement code for speech recognition/05  Data for improvement/외국인 음성 데이터셋/Error Information data/태국어/02ThaiErrorInfoDf.p'

ErrorInfoDf.to_pickle(dfPath)

# %%
dfPath = '/content/drive/MyDrive/Data enhancement code for speech recognition/05  Data for improvement/외국인 음성 데이터셋/Error Information data/태국어/02ThaiErrorInfoDf.csv'

ErrorInfoDf.to_csv(dfPath)
