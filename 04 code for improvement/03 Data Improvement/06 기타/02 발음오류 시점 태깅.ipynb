# %% [markdown]
# # 필요 라이브러리 설치

# %%
# !pip3 install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pickle5
#   Downloading pickle5-0.0.12-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (256 kB)
#      |████████████████████████████████| 256 kB 5.3 MB/s
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.12

# %% [markdown]
# # 필요 라이브러리 로드

# %%
import numpy as np
import pandas as pd

from tqdm import tqdm_notebook
from pickle5 import pickle

# %% [markdown]
# # 데이터 로드

# %%
errorInfoPath = '/content/drive/MyDrive/Data enhancement code for speech recognition/05  Data for improvement/외국인 음성 데이터셋/Error Information data/기타/01errorInfoDict.p'
with open(errorInfoPath, "rb") as f:
    errorInfoDict = pickle.load(f)

# %% [markdown]
# # error Tagging DataFrame 생성

# %%
ErrorDict = {
    'file name' : [],
    'file length' : [],
    'number of errors' : [],
    'time of error' : [],
}
for key in tqdm_notebook(list(errorInfoDict)):
    ErrorDict['file name'].append(key)
    ErrorDict['file length'].append(len(errorInfoDict[key]))
    tempErrorTime = []
    for i in range(len(errorInfoDict[key])):
        if errorInfoDict[key][i] == 3:
            tempErrorTime.append(i)
    
    tempErrorSection = []
    for i in range(len(tempErrorTime)-1):
        check = True
        for j in range(tempErrorTime[i] + 1, tempErrorTime[i+1] - 1):
            if errorInfoDict[key][j] != 4:
                check = False
                break
        
        if check:
            tempErrorSection.append((tempErrorTime[i], tempErrorTime[i+1]))
        else:
            tempErrorSection.append((tempErrorTime[i], tempErrorTime[i]))
    
    while True:
        check = True
        for i in range(len(tempErrorSection) - 1):
            if tempErrorSection[i][1] == tempErrorSection[i + 1][0]:
                tempErrorSection[i] = (tempErrorSection[i][0], tempErrorSection[i+1][1])
                check = False
                del tempErrorSection[i+1]
                break
        if check:
            break
            
    for i in range(len(tempErrorSection)):
        tempSection = (tempErrorSection[i][0] * 320, (tempErrorSection[i][1] + 1) * 320)
        tempErrorSection[i] = tempSection

    ErrorDict['number of errors'].append(len(tempErrorSection))
    ErrorDict['time of error'].append(tempErrorSection)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
#   0%|          | 0/227565 [00:00<?, ?it/s]

# %%
ErrorInfoDf = pd.DataFrame(ErrorDict)

# %% [markdown]
# # DataFrame 확인

# %%
ErrorInfoDf
# Out:
#                             file name  file length  number of errors  \
# 0       EX10QC277_EX0891_20211027.wav          307                 1
# 1       EX10QC250_EX0891_20211027.wav          307                 1
# 2       EX10QC273_EX0891_20211027.wav          307                 1
# 3       EX10QC248_EX0891_20211027.wav          307                 1
# 4       EX10QC268_EX0891_20211027.wav          307                 2
# ...                               ...          ...               ...
# 227560  EX56RA127_EX0223_20210804.wav          643                 2
# 227561  EX56RA136_EX0837_20211030.wav          643                 0
# 227562  EX57RA152_EX0121_20210830.wav          643                 0
# 227563  EX57RA167_EX0892_20211029.wav          643                 0
# 227564  EX57RA168_EX0337_20210831.wav          643                 0
#
#                       time of error
# 0                       [(0, 2880)]
# 1                       [(0, 2880)]
# 2                       [(0, 2880)]
# 3                  [(10880, 16320)]
# 4       [(0, 2880), (22720, 24000)]
# ...                             ...
# 227560    [(0, 1600), (5440, 9600)]
# 227561                           []
# 227562                           []
# 227563                           []
# 227564                           []
#
# [227565 rows x 4 columns]

# %%
ErrorInfoDf[ErrorInfoDf['number of errors'] > 0]
# Out:
#                             file name  file length  number of errors  \
# 0       EX10QC277_EX0891_20211027.wav          307                 1
# 1       EX10QC250_EX0891_20211027.wav          307                 1
# 2       EX10QC273_EX0891_20211027.wav          307                 1
# 3       EX10QC248_EX0891_20211027.wav          307                 1
# 4       EX10QC268_EX0891_20211027.wav          307                 2
# ...                               ...          ...               ...
# 227546  EX53RA064_EX0135_20210814.wav          643                 1
# 227547  EX53RA064_EX0208_20210827.wav          643                 1
# 227549  EX54RA076_EX0784_20211121.wav          643                 1
# 227551  EX54RA085_EX0150_20210813.wav          643                 1
# 227560  EX56RA127_EX0223_20210804.wav          643                 2
#
#                       time of error
# 0                       [(0, 2880)]
# 1                       [(0, 2880)]
# 2                       [(0, 2880)]
# 3                  [(10880, 16320)]
# 4       [(0, 2880), (22720, 24000)]
# ...                             ...
# 227546                  [(0, 1600)]
# 227547                  [(0, 1600)]
# 227549           [(135680, 136960)]
# 227551             [(71040, 72320)]
# 227560    [(0, 1600), (5440, 9600)]
#
# [37086 rows x 4 columns]

# %% [markdown]
# # DataFrame 저장

# %%
dfPath = '/content/drive/MyDrive/Data enhancement code for speech recognition/05  Data for improvement/외국인 음성 데이터셋/Error Information data/기타/02OtherErrorInfoDf.p'

ErrorInfoDf.to_pickle(dfPath)

# %%
dfPath = '/content/drive/MyDrive/Data enhancement code for speech recognition/05  Data for improvement/외국인 음성 데이터셋/Error Information data/기타/02OtherErrorInfoDf.csv'

ErrorInfoDf.to_csv(dfPath)
