# %% [markdown]
# # 필요 라이브러리 설치

# %%
# !pip3 install pickle5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pickle5
#   Downloading pickle5-0.0.12-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (256 kB)
#      |████████████████████████████████| 256 kB 6.6 MB/s
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.12

# %% [markdown]
# # 필요 라이브러리 로드

# %%
import numpy as np
import pandas as pd

from tqdm import tqdm_notebook
from pickle5 import pickle

# %% [markdown]
# # 데이터 로드

# %%
errorInfoPath = '/content/drive/MyDrive/Data enhancement code for speech recognition/05  Data for improvement/외국인 음성 데이터셋/Error Information data/일본어/01errorInfoDict.p'
with open(errorInfoPath, "rb") as f:
    errorInfoDict = pickle.load(f)

# %% [markdown]
# # error Tagging DataFrame 생성

# %%
ErrorDict = {
    'file name' : [],
    'file length' : [],
    'number of errors' : [],
    'time of error' : [],
}
for key in tqdm_notebook(list(errorInfoDict)):
    ErrorDict['file name'].append(key)
    ErrorDict['file length'].append(len(errorInfoDict[key]))
    tempErrorTime = []
    for i in range(len(errorInfoDict[key])):
        if errorInfoDict[key][i] == 3:
            tempErrorTime.append(i)
    
    tempErrorSection = []
    for i in range(len(tempErrorTime)-1):
        check = True
        for j in range(tempErrorTime[i] + 1, tempErrorTime[i+1] - 1):
            if errorInfoDict[key][j] != 4:
                check = False
                break
        
        if check:
            tempErrorSection.append((tempErrorTime[i], tempErrorTime[i+1]))
        else:
            tempErrorSection.append((tempErrorTime[i], tempErrorTime[i]))
    
    while True:
        check = True
        for i in range(len(tempErrorSection) - 1):
            if tempErrorSection[i][1] == tempErrorSection[i + 1][0]:
                tempErrorSection[i] = (tempErrorSection[i][0], tempErrorSection[i+1][1])
                check = False
                del tempErrorSection[i+1]
                break
        if check:
            break

    for i in range(len(tempErrorSection)):
        tempSection = (tempErrorSection[i][0] * 320, (tempErrorSection[i][1] + 1) * 320)
        tempErrorSection[i] = tempSection

    ErrorDict['number of errors'].append(len(tempErrorSection))
    ErrorDict['time of error'].append(tempErrorSection)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
#   0%|          | 0/138622 [00:00<?, ?it/s]

# %%
ErrorInfoDf = pd.DataFrame(ErrorDict)

# %% [markdown]
# # DataFrame 확인

# %%
ErrorInfoDf
# Out:
#                             file name  file length  number of errors  \
# 0       JP10QC248_JP0166_20210806.wav          342                 2
# 1       JP10QC276_JP0106_20210731.wav          342                 1
# 2       JP10QC247_JP0045_20210731.wav          342                 1
# 3       JP10QC291_JP0024_20210731.wav          342                 1
# 4       JP10QC270_JP0011_20210731.wav          342                 2
# ...                               ...          ...               ...
# 138617  JP47RB169_JP0220_20210930.wav          668                 0
# 138618  JP47RB170_JP0220_20210930.wav          668                 0
# 138619  JP48RB194_JP0104_20210803.wav          668                 0
# 138620  JP49RB204_JP0203_20211112.wav          668                 0
# 138621  JP49RB204_JP0222_20211004.wav          668                 0
#
#                       time of error
# 0       [(0, 3840), (13120, 17280)]
# 1                       [(0, 1600)]
# 2                  [(31040, 35200)]
# 3                       [(0, 1600)]
# 4       [(0, 3840), (28160, 33600)]
# ...                             ...
# 138617                           []
# 138618                           []
# 138619                           []
# 138620                           []
# 138621                           []
#
# [138622 rows x 4 columns]

# %%
ErrorInfoDf[ErrorInfoDf['number of errors'] > 0]
# Out:
#                             file name  file length  number of errors  \
# 0       JP10QC248_JP0166_20210806.wav          342                 2
# 1       JP10QC276_JP0106_20210731.wav          342                 1
# 2       JP10QC247_JP0045_20210731.wav          342                 1
# 3       JP10QC291_JP0024_20210731.wav          342                 1
# 4       JP10QC270_JP0011_20210731.wav          342                 2
# ...                               ...          ...               ...
# 138587  JP46RB137_JP0092_20210812.wav          668                 5
# 138589  JP46RB147_JP0179_20210827.wav          668                 1
# 138603  JP49RB218_JP0043_20210826.wav          668                 1
# 138613  JP45RB110_JP0200_20210828.wav          668                 3
# 138615  JP46RB136_JP0021_20210804.wav          668                 1
#
#                                             time of error
# 0                             [(0, 3840), (13120, 17280)]
# 1                                             [(0, 1600)]
# 2                                        [(31040, 35200)]
# 3                                             [(0, 1600)]
# 4                             [(0, 3840), (28160, 33600)]
# ...                                                   ...
# 138587  [(0, 7680), (32320, 40320), (82240, 82560), (1...
# 138589                                        [(0, 1600)]
# 138603                                        [(0, 1600)]
# 138613     [(320, 640), (16320, 17600), (103360, 104640)]
# 138615                                        [(0, 2880)]
#
# [24647 rows x 4 columns]

# %% [markdown]
# # DataFrame 저장

# %%
dfPath = '/content/drive/MyDrive/Data enhancement code for speech recognition/05  Data for improvement/외국인 음성 데이터셋/Error Information data/일본어/02JapanErrorInfoDf.p'

ErrorInfoDf.to_pickle(dfPath)

# %%
dfPath = '/content/drive/MyDrive/Data enhancement code for speech recognition/05  Data for improvement/외국인 음성 데이터셋/Error Information data/일본어/02JapanErrorInfoDf.csv'

ErrorInfoDf.to_csv(dfPath)
